# %%
"""
Here, we are creating the source and destination paths to be used for copying csv files from the workspace repo to a Unity Catalog Volume.
"""
# Programmatic method of getting the user_id from within Databricks
user_id = spark.sql('select current_user() as user').collect()[0]['user']

# Path to Repo location where csv files can be found
source = f"file:/Workspace/Repos/{user_id}/workshop/fixtures/sample_data/csv_files"

# Path to Volumes where we would like to copy the files for Unity Catalog controlled future access
destination = "/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files"

# %%
# Debug tool in case of errors
print(source, destination)
# Out:
# file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files

# %%
# Debug tool in case of errors
print(dbutils.fs.ls(source))
# Out:
# [FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/Directconnectlogin.csv', name='Directconnectlogin.csv', size=130, modificationTime=1705116863889), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/NotificationContactDetail.csv', name='NotificationContactDetail.csv', size=225, modificationTime=1705116863898), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/GeneratedTransactionActivity.csv', name='GeneratedTransactionActivity.csv', size=1232, modificationTime=1705116863930), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/RecipientAccount.csv', name='RecipientAccount.csv', size=187, modificationTime=1705116863962), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/CustomerPIIData.csv', name='CustomerPIIData.csv', size=676, modificationTime=1705116863975), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/EStatementData.csv', name='EStatementData.csv', size=368, modificationTime=1705116863982), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/UserLevelGTEntitlements.csv', name='UserLevelGTEntitlements.csv', size=261, modificationTime=1705116863989), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/AuthorizingGTDevice.csv', name='AuthorizingGTDevice.csv', size=217, modificationTime=1705116864024), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/PhoneNumber.csv', name='PhoneNumber.csv', size=181, modificationTime=1705116864030), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/RecurringTransactions.csv', name='RecurringTransactions.csv', size=724, modificationTime=1705116864044), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/UserAccountNickName.csv', name='UserAccountNickName.csv', size=179, modificationTime=1705116864051), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/UserLogon.csv', name='UserLogon.csv', size=451, modificationTime=1705116864084), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/UserAdmin.csv', name='UserAdmin.csv', size=603, modificationTime=1705116864104), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/TemplatePayments.csv', name='TemplatePayments.csv', size=326, modificationTime=1705116864111), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/Templates.csv', name='Templates.csv', size=502, modificationTime=1705116864118), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/PFMTransactionClassifications.csv', name='PFMTransactionClassifications.csv', size=521, modificationTime=1705116864125), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/LogonActivity.csv', name='LogonActivity.csv', size=720, modificationTime=1705116864132), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/UserEnabledAlerts.csv', name='UserEnabledAlerts.csv', size=473, modificationTime=1705116864139), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/Recipient.csv', name='Recipient.csv', size=426, modificationTime=1705116864146), FileInfo(path='file:/Workspace/Repos/david.finch@databricks.com/workshop/fixtures/sample_data/csv_files/UserAccountData.csv', name='UserAccountData.csv', size=513, modificationTime=1705 ...

# %%
"""
Copy files from source to destination
"""
dbutils.fs.cp(source,destination,recurse=True)
# Out:
# True

# %%
# Debug tool in case of errors
print(dbutils.fs.ls(destination))
# Out:
# [FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Account Notification.csv', name='Account Notification.csv', size=372, modificationTime=1705458711000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Aggregates.csv', name='Aggregates.csv', size=285, modificationTime=1705458711000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuditScore.csv', name='AuditScore.csv', size=369, modificationTime=1705458717000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuthorizingGTDevice.csv', name='AuthorizingGTDevice.csv', size=217, modificationTime=1705458689000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/ClosedAccountData.csv', name='ClosedAccountData.csv', size=571, modificationTime=1705458721000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerEnabledTreasuryFeatures.csv', name='CustomerEnabledTreasuryFeatures.csv', size=409, modificationTime=1705458718000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerGTLimits.csv', name='CustomerGTLimits.csv', size=359, modificationTime=1705458715000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerLevelGTEntitlements.csv', name='CustomerLevelGTEntitlements.csv', size=243, modificationTime=1705458701000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerPIIData.csv', name='CustomerPIIData.csv', size=676, modificationTime=1705458687000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DeliveredSecurityAlert.csv', name='DeliveredSecurityAlert.csv', size=446, modificationTime=1705458713000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DirectConnectTransactions.csv', name='DirectConnectTransactions.csv', size=233, modificationTime=1705458720000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Directconnectlogin.csv', name='Directconnectlogin.csv', size=130, modificationTime=1705458683000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DisclaimerAcceptance.csv', name='DisclaimerAcceptance.csv', size=194, modificationTime=1705458709000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/EStatementData.csv', name='EStatementData.csv', size=368, modificationTime=1705458688000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedACHActivity.csv', name='GeneratedACHActivity.csv', size=348, modificationTime=1705458706000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedTransactionActivity.csv', name='GeneratedTransactionActivity.csv', size=1232, modificationTime=1705458685000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GoalsData.csv', name='GoalsData.csv', size=713, modificationTime=1705458716000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/LogonActivity.csv', name='LogonActivity.csv', size=720, modificationTime=1705458698000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/LogonAuthenticationDetail.csv', name='LogonAuthenticationDetail.csv', size=706, modificationTime=1705458708000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/NotificationContactDetail.csv', name='NotificationContactDetail.csv', size=225, modificationTime=1705458684000), FileInfo(path='dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/PFMHostAccountDataElements.csv', name= ...

# %%
"""
First, we list all files copied into the Unity Catalog Volume using dbutils. The returned list is actually a list of objects which have certain properties such as "name" and "path" which can be returned using (.)notation such as object.name
"""
# Storage account information
storage_account = "ubsadatabrickspoc2"
storage_container = "databricks-poc"

# Get list of files from Volumes
source_files = dbutils.fs.ls("/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files")

# For each file object in list of file objects
for source_file in source_files:
    """
    This section is used to parse & clean the input directory objects, and to create the three destination paths. 
    """
    # Path to the csv file
    csv_path = source_file.path
    print(f"Processing CSV File: {csv_path}")
    
    # Name of the csv file slightly cleaned (all lowercase, " " replaced with "_", and any "." removed)
    name = "_".join(source_file.name.split(".")[:-1]).replace(" ", "_").lower()
    print(f"Cleaned file name: {name}")

    # Path to Volumes where "||" delim file will be saved
    pipe_delim_path = f"/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/{name}"
    print(f"Volume Destination Path for || delim file: {pipe_delim_path}")

    # Path to landing zone in ADLS where "||" delim file will be saved
    auto_loader_path = f"abfss://{storage_container}@{storage_account}.dfs.core.windows.net/umpqua_poc/landing_zone/{name}"
    print(f"Landing Zone Destination Path for || delim file: {auto_loader_path}")

    # Unity Catalog path to create test table
    table_path = f"umpqua_poc_dev.bronze_data.test_{name}"
    print(f"Unity Catalog Test Table Path: {table_path}")


    """
    Here, we will read the "," delimited csv file; write it to a Unity Catalog Volume as a "||" delimited csv file; write it to our simulated landing zone as a "||" delimited file (AutoLoader will be used to process files from this location); and finally we will create a Unity Catalog Delta Table. These are redundant and largely unecessary steps that are being done simply to illustrate the process. 
    """
    # Read the csv file with "," delimiter; with first row as header; without inferring the schema
    print(f"Reading CSV File: {csv_path}")
    df = spark.read.format("csv").option("delimiter", ",").option("header", "True").load(csv_path)
    print(f"Successfully Read CSV File: {csv_path}")

    # Write csv file as "||" delim to Volumes for easy access in the future; Including the header; Overwriting any existing data
    print(f"Saving to Volume: {pipe_delim_path}")
    df.write.csv(path=pipe_delim_path, sep="||", header=True, mode="overwrite")
    print(f"Successfully Wrote to Volume: {pipe_delim_path}")

    # Write csv file as "||" delim to ADLS landing zone; Including the header; Overwriting any existing data; 
    # This will be the AutoLoader target
    print(f"Saving to landing zone: {auto_loader_path}")
    df.write.csv(path=auto_loader_path,sep="||",header=True,mode="overwrite")
    print(f"Successfully Wrote to Landing Zone: {auto_loader_path}")

    # Save as Delta table in Unity Catalog
    print(f"Creating test table: {table_path}")
    df.write.format("delta").mode("overwrite").saveAsTable(table_path)
    print(f"Successfully Saved to Unity Catalog Delta Table: {table_path}")
# Out:
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Account Notification.csv
# Cleaned file name: account_notification
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/account_notification
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/account_notification
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_account_notification
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Account Notification.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Account Notification.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/account_notification
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/account_notification
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/account_notification
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/account_notification
# Creating test table: umpqua_poc_dev.bronze_data.test_account_notification
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_account_notification
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Aggregates.csv
# Cleaned file name: aggregates
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/aggregates
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/aggregates
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_aggregates
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Aggregates.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Aggregates.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/aggregates
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/aggregates
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/aggregates
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/aggregates
# Creating test table: umpqua_poc_dev.bronze_data.test_aggregates
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_aggregates
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuditScore.csv
# Cleaned file name: auditscore
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/auditscore
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/auditscore
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_auditscore
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuditScore.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuditScore.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/auditscore
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/auditscore
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/auditscore
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/auditscore
# Creating test table: umpqua_poc_dev.bronze_data.test_auditscore
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_auditscore
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuthorizingGTDevice.csv
# Cleaned file name: authorizinggtdevice
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/authorizinggtdevice
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/authorizinggtdevice
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_authorizinggtdevice
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuthorizingGTDevice.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/AuthorizingGTDevice.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/authorizinggtdevice
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/authorizinggtdevice
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/authorizinggtdevice
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/authorizinggtdevice
# Creating test table: umpqua_poc_dev.bronze_data.test_authorizinggtdevice
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_authorizinggtdevice
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/ClosedAccountData.csv
# Cleaned file name: closedaccountdata
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/closedaccountdata
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/closedaccountdata
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_closedaccountdata
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/ClosedAccountData.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/ClosedAccountData.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/closedaccountdata
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/closedaccountdata
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/closedaccountdata
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/closedaccountdata
# Creating test table: umpqua_poc_dev.bronze_data.test_closedaccountdata
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_closedaccountdata
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerEnabledTreasuryFeatures.csv
# Cleaned file name: customerenabledtreasuryfeatures
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerenabledtreasuryfeatures
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerenabledtreasuryfeatures
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_customerenabledtreasuryfeatures
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerEnabledTreasuryFeatures.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerEnabledTreasuryFeatures.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerenabledtreasuryfeatures
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerenabledtreasuryfeatures
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerenabledtreasuryfeatures
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerenabledtreasuryfeatures
# Creating test table: umpqua_poc_dev.bronze_data.test_customerenabledtreasuryfeatures
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_customerenabledtreasuryfeatures
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerGTLimits.csv
# Cleaned file name: customergtlimits
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customergtlimits
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customergtlimits
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_customergtlimits
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerGTLimits.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerGTLimits.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customergtlimits
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customergtlimits
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customergtlimits
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customergtlimits
# Creating test table: umpqua_poc_dev.bronze_data.test_customergtlimits
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_customergtlimits
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerLevelGTEntitlements.csv
# Cleaned file name: customerlevelgtentitlements
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerlevelgtentitlements
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerlevelgtentitlements
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_customerlevelgtentitlements
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerLevelGTEntitlements.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerLevelGTEntitlements.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerlevelgtentitlements
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerlevelgtentitlements
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerlevelgtentitlements
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerlevelgtentitlements
# Creating test table: umpqua_poc_dev.bronze_data.test_customerlevelgtentitlements
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_customerlevelgtentitlements
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerPIIData.csv
# Cleaned file name: customerpiidata
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerpiidata
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerpiidata
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_customerpiidata
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerPIIData.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/CustomerPIIData.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerpiidata
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/customerpiidata
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerpiidata
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/customerpiidata
# Creating test table: umpqua_poc_dev.bronze_data.test_customerpiidata
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_customerpiidata
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DeliveredSecurityAlert.csv
# Cleaned file name: deliveredsecurityalert
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/deliveredsecurityalert
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/deliveredsecurityalert
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_deliveredsecurityalert
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DeliveredSecurityAlert.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DeliveredSecurityAlert.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/deliveredsecurityalert
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/deliveredsecurityalert
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/deliveredsecurityalert
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/deliveredsecurityalert
# Creating test table: umpqua_poc_dev.bronze_data.test_deliveredsecurityalert
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_deliveredsecurityalert
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DirectConnectTransactions.csv
# Cleaned file name: directconnecttransactions
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/directconnecttransactions
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/directconnecttransactions
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_directconnecttransactions
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DirectConnectTransactions.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DirectConnectTransactions.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/directconnecttransactions
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/directconnecttransactions
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/directconnecttransactions
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/directconnecttransactions
# Creating test table: umpqua_poc_dev.bronze_data.test_directconnecttransactions
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_directconnecttransactions
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Directconnectlogin.csv
# Cleaned file name: directconnectlogin
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/directconnectlogin
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/directconnectlogin
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_directconnectlogin
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Directconnectlogin.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Directconnectlogin.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/directconnectlogin
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/directconnectlogin
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/directconnectlogin
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/directconnectlogin
# Creating test table: umpqua_poc_dev.bronze_data.test_directconnectlogin
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_directconnectlogin
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DisclaimerAcceptance.csv
# Cleaned file name: disclaimeracceptance
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/disclaimeracceptance
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/disclaimeracceptance
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_disclaimeracceptance
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DisclaimerAcceptance.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/DisclaimerAcceptance.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/disclaimeracceptance
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/disclaimeracceptance
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/disclaimeracceptance
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/disclaimeracceptance
# Creating test table: umpqua_poc_dev.bronze_data.test_disclaimeracceptance
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_disclaimeracceptance
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/EStatementData.csv
# Cleaned file name: estatementdata
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/estatementdata
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/estatementdata
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_estatementdata
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/EStatementData.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/EStatementData.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/estatementdata
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/estatementdata
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/estatementdata
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/estatementdata
# Creating test table: umpqua_poc_dev.bronze_data.test_estatementdata
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_estatementdata
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedACHActivity.csv
# Cleaned file name: generatedachactivity
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/generatedachactivity
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/generatedachactivity
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_generatedachactivity
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedACHActivity.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedACHActivity.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/generatedachactivity
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/generatedachactivity
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/generatedachactivity
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/generatedachactivity
# Creating test table: umpqua_poc_dev.bronze_data.test_generatedachactivity
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_generatedachactivity
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedTransactionActivity.csv
# Cleaned file name: generatedtransactionactivity
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/generatedtransactionactivity
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/generatedtransactionactivity
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_generatedtransactionactivity
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedTransactionActivity.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GeneratedTransactionActivity.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/generatedtransactionactivity
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/generatedtransactionactivity
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/generatedtransactionactivity
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/generatedtransactionactivity
# Creating test table: umpqua_poc_dev.bronze_data.test_generatedtransactionactivity
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_generatedtransactionactivity
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GoalsData.csv
# Cleaned file name: goalsdata
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/goalsdata
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/goalsdata
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_goalsdata
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GoalsData.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/GoalsData.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/goalsdata
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/goalsdata
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/goalsdata
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/goalsdata
# Creating test table: umpqua_poc_dev.bronze_data.test_goalsdata
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_goalsdata
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/LogonActivity.csv
# Cleaned file name: logonactivity
# Volume Destination Path for || delim file: /Volumes/umpqu
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# onze_data/bronze_volume/sample_data/pipe_delim_files/recipientfi
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/recipientfi
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_recipientfi
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RecipientFI.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RecipientFI.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/recipientfi
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/recipientfi
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/recipientfi
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/recipientfi
# Creating test table: umpqua_poc_dev.bronze_data.test_recipientfi
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_recipientfi
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RecurringTransactions.csv
# Cleaned file name: recurringtransactions
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/recurringtransactions
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/recurringtransactions
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_recurringtransactions
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RecurringTransactions.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RecurringTransactions.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/recurringtransactions
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/recurringtransactions
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/recurringtransactions
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/recurringtransactions
# Creating test table: umpqua_poc_dev.bronze_data.test_recurringtransactions
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_recurringtransactions
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RemoteDepositActivity.csv
# Cleaned file name: remotedepositactivity
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/remotedepositactivity
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/remotedepositactivity
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_remotedepositactivity
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RemoteDepositActivity.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/RemoteDepositActivity.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/remotedepositactivity
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/remotedepositactivity
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/remotedepositactivity
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/remotedepositactivity
# Creating test table: umpqua_poc_dev.bronze_data.test_remotedepositactivity
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_remotedepositactivity
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Subsidiary.csv
# Cleaned file name: subsidiary
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/subsidiary
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/subsidiary
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_subsidiary
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Subsidiary.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Subsidiary.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/subsidiary
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/subsidiary
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/subsidiary
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/subsidiary
# Creating test table: umpqua_poc_dev.bronze_data.test_subsidiary
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_subsidiary
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/TemplatePayments.csv
# Cleaned file name: templatepayments
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/templatepayments
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/templatepayments
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_templatepayments
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/TemplatePayments.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/TemplatePayments.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/templatepayments
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/templatepayments
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/templatepayments
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/templatepayments
# Creating test table: umpqua_poc_dev.bronze_data.test_templatepayments
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_templatepayments
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Templates.csv
# Cleaned file name: templates
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/templates
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/templates
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_templates
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Templates.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/Templates.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/templates
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/templates
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/templates
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/templates
# Creating test table: umpqua_poc_dev.bronze_data.test_templates
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_templates
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/ThirdPartyData.csv
# Cleaned file name: thirdpartydata
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/thirdpartydata
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/thirdpartydata
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_thirdpartydata
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/ThirdPartyData.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/ThirdPartyData.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/thirdpartydata
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/thirdpartydata
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/thirdpartydata
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/thirdpartydata
# Creating test table: umpqua_poc_dev.bronze_data.test_thirdpartydata
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_thirdpartydata
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UnProcessedTransactions.csv
# Cleaned file name: unprocessedtransactions
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/unprocessedtransactions
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/unprocessedtransactions
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_unprocessedtransactions
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UnProcessedTransactions.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UnProcessedTransactions.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/unprocessedtransactions
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/unprocessedtransactions
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/unprocessedtransactions
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/unprocessedtransactions
# Creating test table: umpqua_poc_dev.bronze_data.test_unprocessedtransactions
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_unprocessedtransactions
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAccountData.csv
# Cleaned file name: useraccountdata
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useraccountdata
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useraccountdata
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_useraccountdata
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAccountData.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAccountData.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useraccountdata
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useraccountdata
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useraccountdata
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useraccountdata
# Creating test table: umpqua_poc_dev.bronze_data.test_useraccountdata
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_useraccountdata
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAccountNickName.csv
# Cleaned file name: useraccountnickname
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useraccountnickname
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useraccountnickname
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_useraccountnickname
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAccountNickName.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAccountNickName.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useraccountnickname
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useraccountnickname
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useraccountnickname
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useraccountnickname
# Creating test table: umpqua_poc_dev.bronze_data.test_useraccountnickname
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_useraccountnickname
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAdmin.csv
# Cleaned file name: useradmin
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useradmin
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useradmin
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_useradmin
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAdmin.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserAdmin.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useradmin
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/useradmin
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useradmin
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/useradmin
# Creating test table: umpqua_poc_dev.bronze_data.test_useradmin
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_useradmin
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserData.csv
# Cleaned file name: userdata
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userdata
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userdata
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_userdata
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserData.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserData.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userdata
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userdata
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userdata
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userdata
# Creating test table: umpqua_poc_dev.bronze_data.test_userdata
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_userdata
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserDataPII.csv
# Cleaned file name: userdatapii
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userdatapii
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userdatapii
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_userdatapii
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserDataPII.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserDataPII.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userdatapii
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userdatapii
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userdatapii
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userdatapii
# Creating test table: umpqua_poc_dev.bronze_data.test_userdatapii
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_userdatapii
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserEnabledAlerts.csv
# Cleaned file name: userenabledalerts
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userenabledalerts
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userenabledalerts
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_userenabledalerts
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserEnabledAlerts.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserEnabledAlerts.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userenabledalerts
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userenabledalerts
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userenabledalerts
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userenabledalerts
# Creating test table: umpqua_poc_dev.bronze_data.test_userenabledalerts
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_userenabledalerts
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserEnrollment.csv
# Cleaned file name: userenrollment
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userenrollment
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userenrollment
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_userenrollment
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserEnrollment.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserEnrollment.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userenrollment
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userenrollment
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userenrollment
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userenrollment
# Creating test table: umpqua_poc_dev.bronze_data.test_userenrollment
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_userenrollment
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserLevelGTEntitlements.csv
# Cleaned file name: userlevelgtentitlements
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userlevelgtentitlements
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userlevelgtentitlements
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_userlevelgtentitlements
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserLevelGTEntitlements.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserLevelGTEntitlements.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userlevelgtentitlements
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userlevelgtentitlements
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userlevelgtentitlements
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userlevelgtentitlements
# Creating test table: umpqua_poc_dev.bronze_data.test_userlevelgtentitlements
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_userlevelgtentitlements
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserLogon.csv
# Cleaned file name: userlogon
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userlogon
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userlogon
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_userlogon
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserLogon.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserLogon.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userlogon
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userlogon
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userlogon
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userlogon
# Creating test table: umpqua_poc_dev.bronze_data.test_userlogon
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_userlogon
# Processing CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserThemes.csv
# Cleaned file name: userthemes
# Volume Destination Path for || delim file: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userthemes
# Landing Zone Destination Path for || delim file: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userthemes
# Unity Catalog Test Table Path: umpqua_poc_dev.bronze_data.test_userthemes
# Reading CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserThemes.csv
# Successfully Read CSV File: dbfs:/Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/csv_files/UserThemes.csv
# Saving to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userthemes
# Successfully Wrote to Volume: /Volumes/umpqua_poc_dev/bronze_data/bronze_volume/sample_data/pipe_delim_files/userthemes
# Saving to landing zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userthemes
# Successfully Wrote to Landing Zone: abfss://databricks-poc@oneenvadls.dfs.core.windows.net/umpqua_poc/landing_zone/userthemes
# Creating test table: umpqua_poc_dev.bronze_data.test_userthemes
# Successfully Saved to Unity Catalog Delta Table: umpqua_poc_dev.bronze_data.test_userthemes
